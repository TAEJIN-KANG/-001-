# %% [markdown]
# <a href="https://colab.research.google.com/github/TAEJIN-KANG/-001-/blob/main/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_3%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C_20248191_%EA%B0%95%ED%83%9C%EC%A7%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, 3)

grid = plt.GridSpec(3,3, wspace=0.4, hspace=0.3)
X = np.random.randn(100)
Y = np.random.randn(100)
plt.subplot(grid[0, :]).scatter(X, Y)

x = np.linspace(1.0, 4.0, 100)
y = np.linspace(0, 4, 100)
plt.yticks(np.arange(2,5,2))
plt.subplot(grid[1, :2]).plot(x, y, linestyle='dotted',  color='r')

X = np.linspace(0, 10, 100)
Y = np.cos(X)
plt.subplot(grid[2, 0]).plot(X, Y, color='g')

X = np.arange(10)
Y = np.abs(np.random.randn(10)*10)
plt.subplot(grid[2, 1]).bar(X, Y)

Z = np.random.uniform(0,1,(10,5))
plt.subplot(grid[1:, 2]).imshow(Z)
# Out:
# <ipython-input-33-ca39ff9ed927>:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0, :]).scatter(X, Y)
# <ipython-input-33-ca39ff9ed927>:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1, :2]).plot(x, y, linestyle='dotted',  color='r')
# <ipython-input-33-ca39ff9ed927>:18: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[2, 0]).plot(X, Y, color='g')
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1.0, 4.0, 100)
y = np.linspace(0, 4, 100)

plt.yticks(np.arange(2,5,2))

plt.plot(x, y, linestyle='dotted',  color='r')
plt.show()
